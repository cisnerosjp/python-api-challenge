# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | la passe
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | ixtapa
# Processing Record 4 of Set 1 | rasht
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | hamilton
# Processing Record 8 of Set 1 | bamboo flat
# Processing Record 9 of Set 1 | biryusinsk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nova sintra
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | surgana
# Processing Record 14 of Set 1 | kidal
# Processing Record 15 of Set 1 | gadzhiyevo
# Processing Record 16 of Set 1 | hawaiian paradise park
# Processing Record 17 of Set 1 | inarajan village
# Processing Record 18 of Set 1 | veseloyarsk
# Processing Record 19 of Set 1 | yermakovskoye
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | stanley
# Processing Record 23 of Set 1 | waitangi
# Processing Record 24 of Set 1 | adamstown
# Processing Record 25 of Set 1 | kenai
# Processing Record 26 of Set 1 | mili
# Processing Record 27 of Set 1 | les sables-d'olonne
# Processing Record 28 of Set 1 | vallenar
# Processing Record 29 of Set 1 | farmville
# Processing Record 30 of Set 1 | leirvik
# Processing Record 31 of Set 1 | margaret river
# Processing Record 32 of Set 1 | smithers
# Processing Record 33 of Set 1 | lihue
# Processing Record 34 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | antsiranana
# Processing Record 37 of Set 1 | konarka
# Processing Record 38 of Set 1 | college
# Processing Record 39 of Set 1 | tura
# Processing Record 40 of Set 1 | levis
# Processing Record 41 of Set 1 | ust-nera
# Processing Record 42 of Set 1 | taltal
# Processing Record 43 of Set 1 | bilibino
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | iskateley
# Processing Record 46 of Set 1 | peruibe
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | puerto natales
# Processing Record 49 of Set 1 | agat village
# Processing Record 50 of Set 1 | nizhnyaya omka
# Processing Record 0 of Set 2 | aasiaat
# Processing Record 1 of Set 2 | moyynkum
# Processing Record 2 of Set 2 | vernon
# Processing Record 3 of Set 2 | port-aux-francais
# Processing Record 4 of Set 2 | pangody
# Processing Record 5 of Set 2 | cheongsong gun
# Processing Record 6 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 7 of Set 2 | papatowai
# Processing Record 8 of Set 2 | alamosa
# Processing Record 9 of Set 2 | zangguy
# City not found. Skipping...
# Processing Record 10 of Set 2 | murwara
# Processing Record 11 of Set 2 | klyuchi
# Processing Record 12 of Set 2 | sisimiut
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | harstad
# Processing Record 15 of Set 2 | rongelap
# Processing Record 16 of Set 2 | zhaotong
# Processing Record 17 of Set 2 | severo-yeniseyskiy
# Processing Record 18 of Set 2 | pamanukan
# Processing Record 19 of Set 2 | kikwit
# Processing Record 20 of Set 2 | mata-utu
# Processing Record 21 of Set 2 | wailua homesteads
# Processing Record 22 of Set 2 | utrik
# Processing Record 23 of Set 2 | cachoeiras de macacu
# Processing Record 24 of Set 2 | invercargill
# Processing Record 25 of Set 2 | pesqueira
# Processing Record 26 of Set 2 | igrim
# Processing Record 27 of Set 2 | plastun
# Processing Record 28 of Set 2 | gorontalo
# Processing Record 29 of Set 2 | kingscliff
# Processing Record 30 of Set 2 | gorgan
# Processing Record 31 of Set 2 | diamantina
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | kerikeri
# Processing Record 34 of Set 2 | taro
# Processing Record 35 of Set 2 | las tablas
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | murun-kuren
# Processing Record 38 of Set 2 | palmer
# Processing Record 39 of Set 2 | vila velha
# Processing Record 40 of Set 2 | troitskoye
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | villa regina
# Processing Record 44 of Set 2 | colonia
# Processing Record 45 of Set 2 | srikakulam
# Processing Record 46 of Set 2 | muroto-misakicho
# Processing Record 47 of Set 2 | saacow
# Processing Record 48 of Set 2 | edinburgh of the seven seas
# Processing Record 49 of Set 2 | queenstown
# Processing Record 0 of Set 3 | kone
# Processing Record 1 of Set 3 | saint-joseph
# Processing Record 2 of Set 3 | arno
# Processing Record 3 of Set 3 | lolodorf
# Processing Record 4 of Set 3 | ormara
# Processing Record 5 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 3 | tefe
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | taiyuan
# Processing Record 9 of Set 3 | saint-pierre
# Processing Record 10 of Set 3 | hinton
# Processing Record 11 of Set 3 | sierra grande
# Processing Record 12 of Set 3 | khandyga
# Processing Record 13 of Set 3 | pedernales
# Processing Record 14 of Set 3 | saipan
# Processing Record 15 of Set 3 | hadibu
# Processing Record 16 of Set 3 | qaqortoq
# Processing Record 17 of Set 3 | marudi
# City not found. Skipping...
# Processing Record 18 of Set 3 | la'ie
# Processing Record 19 of Set 3 | kronenwetter
# Processing Record 20 of Set 3 | blackmans bay
# Processing Record 21 of Set 3 | pailin
# Processing Record 22 of Set 3 | cochrane
# Processing Record 23 of Set 3 | madalena
# Processing Record 24 of Set 3 | tazovsky
# Processing Record 25 of Set 3 | moyale
# Processing Record 26 of Set 3 | badger
# Processing Record 27 of Set 3 | kangasniemi
# Processing Record 28 of Set 3 | tralee
# Processing Record 29 of Set 3 | atafu village
# Processing Record 30 of Set 3 | tasqala
# Processing Record 31 of Set 3 | whitehorse
# Processing Record 32 of Set 3 | port glaud
# City not found. Skipping...
# Processing Record 33 of Set 3 | az zuwaytinah
# Processing Record 34 of Set 3 | kamloops
# Processing Record 35 of Set 3 | mhangura
# Processing Record 36 of Set 3 | isafjordur
# Processing Record 37 of Set 3 | kayyerkan
# Processing Record 38 of Set 3 | iqaluit
# Processing Record 39 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 40 of Set 3 | nagqu
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | yima
# Processing Record 43 of Set 3 | zhongshan
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | novobureyskiy
# Processing Record 46 of Set 3 | kapuskasing
# Processing Record 47 of Set 3 | malanje
# Processing Record 48 of Set 3 | nova vicosa
# Processing Record 49 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 0 of Set 4 | touros
# Processing Record 1 of Set 4 | st. john's
# Processing Record 2 of Set 4 | rodolfo sanchez taboada
# Processing Record 3 of Set 4 | olonkinbyen
# Processing Record 4 of Set 4 | bhatapara
# Processing Record 5 of Set 4 | tucurui
# Processing Record 6 of Set 4 | ambon
# Processing Record 7 of Set 4 | carloforte
# Processing Record 8 of Set 4 | nantucket
# Processing Record 9 of Set 4 | malvan
# Processing Record 10 of Set 4 | jaisalmer
# Processing Record 11 of Set 4 | vorgashor
# Processing Record 12 of Set 4 | suluova
# Processing Record 13 of Set 4 | belmopan
# Processing Record 14 of Set 4 | anadyr
# Processing Record 15 of Set 4 | kapustin yar
# Processing Record 16 of Set 4 | ponteareas
# Processing Record 17 of Set 4 | rosarito
# Processing Record 18 of Set 4 | shevchenkove
# Processing Record 19 of Set 4 | shingu
# Processing Record 20 of Set 4 | montefiascone
# Processing Record 21 of Set 4 | torghay
# Processing Record 22 of Set 4 | el nido
# Processing Record 23 of Set 4 | kulhudhuffushi
# Processing Record 24 of Set 4 | maumere
# Processing Record 25 of Set 4 | newport
# Processing Record 26 of Set 4 | chernyshevsk
# Processing Record 27 of Set 4 | riachao das neves
# Processing Record 28 of Set 4 | timbuktu
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | fort bragg
# Processing Record 31 of Set 4 | holualoa
# Processing Record 32 of Set 4 | fisterra
# Processing Record 33 of Set 4 | yala
# Processing Record 34 of Set 4 | businga
# Processing Record 35 of Set 4 | garissa
# Processing Record 36 of Set 4 | kralendijk
# Processing Record 37 of Set 4 | enkoping
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | felipe carrillo puerto
# Processing Record 40 of Set 4 | borogontsy
# Processing Record 41 of Set 4 | namibe
# Processing Record 42 of Set 4 | freetown
# Processing Record 43 of Set 4 | weno
# Processing Record 44 of Set 4 | balboa
# Processing Record 45 of Set 4 | mahanje
# Processing Record 46 of Set 4 | east ballina
# Processing Record 47 of Set 4 | port elizabeth
# Processing Record 48 of Set 4 | troitsko-pechorsk
# Processing Record 49 of Set 4 | igarka
# Processing Record 0 of Set 5 | vershino-darasunskiy
# Processing Record 1 of Set 5 | serenje
# Processing Record 2 of Set 5 | kargasok
# Processing Record 3 of Set 5 | margate
# Processing Record 4 of Set 5 | trenggalek
# Processing Record 5 of Set 5 | diok'nisi
# Processing Record 6 of Set 5 | chignahuapan
# Processing Record 7 of Set 5 | pionerskiy
# Processing Record 8 of Set 5 | san andres
# Processing Record 9 of Set 5 | siniscola
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | safotu
# Processing Record 12 of Set 5 | marka
# Processing Record 13 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 5 | happy valley-goose bay
# Processing Record 15 of Set 5 | ilulissat
# Processing Record 16 of Set 5 | priozersk
# Processing Record 17 of Set 5 | emerald
# Processing Record 18 of Set 5 | chililabombwe
# Processing Record 19 of Set 5 | olavarria
# Processing Record 20 of Set 5 | udachny
# Processing Record 21 of Set 5 | kamwenge
# Processing Record 22 of Set 5 | tselinnoye
# Processing Record 23 of Set 5 | berdigestyakh
# Processing Record 24 of Set 5 | changyon
# Processing Record 25 of Set 5 | elek
# Processing Record 26 of Set 5 | zhanaozen
# Processing Record 27 of Set 5 | masuguru
# Processing Record 28 of Set 5 | dakhla
# Processing Record 29 of Set 5 | talcahuano
# Processing Record 30 of Set 5 | kirensk
# Processing Record 31 of Set 5 | guane
# Processing Record 32 of Set 5 | sao gabriel da cachoeira
# Processing Record 33 of Set 5 | huarmey
# Processing Record 34 of Set 5 | askoy
# Processing Record 35 of Set 5 | kanel
# Processing Record 36 of Set 5 | lompoc
# Processing Record 37 of Set 5 | san antonio
# Processing Record 38 of Set 5 | dikhil
# Processing Record 39 of Set 5 | tarko-sale
# Processing Record 40 of Set 5 | lazaro cardenas
# Processing Record 41 of Set 5 | buta
# Processing Record 42 of Set 5 | uturoa
# Processing Record 43 of Set 5 | tarinkot
# Processing Record 44 of Set 5 | tofol
# Processing Record 45 of Set 5 | kandi
# Processing Record 46 of Set 5 | rundu
# Processing Record 47 of Set 5 | nuuk
# Processing Record 48 of Set 5 | nawabshah
# Processing Record 49 of Set 5 | yarmouth
# Processing Record 0 of Set 6 | eforie sud
# Processing Record 1 of Set 6 | richards bay
# Processing Record 2 of Set 6 | harper
# Processing Record 3 of Set 6 | talara
# Processing Record 4 of Set 6 | amga
# Processing Record 5 of Set 6 | isangel
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | salekhard
# Processing Record 8 of Set 6 | howrah
# Processing Record 9 of Set 6 | port saint john's
# Processing Record 10 of Set 6 | juneau
# Processing Record 11 of Set 6 | pineville
# Processing Record 12 of Set 6 | dhidhdhoo
# Processing Record 13 of Set 6 | east london
# Processing Record 14 of Set 6 | rio grande
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 6 | belmonte
# Processing Record 18 of Set 6 | buala
# Processing Record 19 of Set 6 | kingston
# Processing Record 20 of Set 6 | shadrinsk
# Processing Record 21 of Set 6 | ilabaya
# Processing Record 22 of Set 6 | tolanaro
# Processing Record 23 of Set 6 | korla
# Processing Record 24 of Set 6 | nemuro
# Processing Record 25 of Set 6 | tchintabaraden
# Processing Record 26 of Set 6 | port mathurin
# Processing Record 27 of Set 6 | deridder
# Processing Record 28 of Set 6 | paradip garh
# Processing Record 29 of Set 6 | shakiso
# Processing Record 30 of Set 6 | homa bay
# Processing Record 31 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 6 | nieves
# Processing Record 33 of Set 6 | ma'rib
# Processing Record 34 of Set 6 | west island
# Processing Record 35 of Set 6 | haiku-pauwela
# Processing Record 36 of Set 6 | al jawf
# Processing Record 37 of Set 6 | lajas
# Processing Record 38 of Set 6 | mariakani
# Processing Record 39 of Set 6 | fale old settlement
# Processing Record 40 of Set 6 | ubari
# Processing Record 41 of Set 6 | kudahuvadhoo
# Processing Record 42 of Set 6 | chudovo
# Processing Record 43 of Set 6 | bardai
# Processing Record 44 of Set 6 | sarykemer
# Processing Record 45 of Set 6 | susuman
# Processing Record 46 of Set 6 | barcelos
# Processing Record 47 of Set 6 | bouza
# Processing Record 48 of Set 6 | san antonio de pale
# Processing Record 49 of Set 6 | iguape
# Processing Record 0 of Set 7 | kulgam
# Processing Record 1 of Set 7 | moapa valley
# Processing Record 2 of Set 7 | kota
# Processing Record 3 of Set 7 | rong'an
# Processing Record 4 of Set 7 | mariehamn
# Processing Record 5 of Set 7 | guipavas
# Processing Record 6 of Set 7 | xingtai
# Processing Record 7 of Set 7 | vilyuchinsk
# Processing Record 8 of Set 7 | pisco
# Processing Record 9 of Set 7 | sur
# Processing Record 10 of Set 7 | port lincoln
# Processing Record 11 of Set 7 | hilo
# Processing Record 12 of Set 7 | rayachoti
# Processing Record 13 of Set 7 | thunder bay
# Processing Record 14 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 15 of Set 7 | padang
# Processing Record 16 of Set 7 | hasaki
# Processing Record 17 of Set 7 | al fallujah
# Processing Record 18 of Set 7 | al qaryatayn
# Processing Record 19 of Set 7 | carnarvon
# Processing Record 20 of Set 7 | thinadhoo
# Processing Record 21 of Set 7 | midvagur
# Processing Record 22 of Set 7 | puerto ayacucho
# Processing Record 23 of Set 7 | gamay
# Processing Record 24 of Set 7 | maxixe
# Processing Record 25 of Set 7 | callao
# Processing Record 26 of Set 7 | newman
# Processing Record 27 of Set 7 | taco pozo
# Processing Record 28 of Set 7 | kushalgarh
# Processing Record 29 of Set 7 | dickinson
# Processing Record 30 of Set 7 | kyshtovka
# Processing Record 31 of Set 7 | constantia
# Processing Record 32 of Set 7 | mar del plata
# Processing Record 33 of Set 7 | preobrazheniye
# Processing Record 34 of Set 7 | chiili
# City not found. Skipping...
# Processing Record 35 of Set 7 | usinsk
# Processing Record 36 of Set 7 | kindia
# Processing Record 37 of Set 7 | saurimo
# Processing Record 38 of Set 7 | rensselaer
# Processing Record 39 of Set 7 | saudarkrokur
# Processing Record 40 of Set 7 | lancaster
# Processing Record 41 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 42 of Set 7 | kuta
# Processing Record 43 of Set 7 | berezovyy
# Processing Record 44 of Set 7 | ayaviri
# Processing Record 45 of Set 7 | leava
# Processing Record 46 of Set 7 | san patricio
# Processing Record 47 of Set 7 | dudinka
# Processing Record 48 of Set 7 | chahal guatemala
# Processing Record 49 of Set 7 | hammerfest
# Processing Record 0 of Set 8 | yabrud
# Processing Record 1 of Set 8 | norilsk
# Processing Record 2 of Set 8 | minas de marcona
# Processing Record 3 of Set 8 | mogocha
# Processing Record 4 of Set 8 | chibougamau
# Processing Record 5 of Set 8 | price
# Processing Record 6 of Set 8 | tabou
# Processing Record 7 of Set 8 | mumbwa
# Processing Record 8 of Set 8 | akrehamn
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | burutu
# Processing Record 11 of Set 8 | camarinas
# Processing Record 12 of Set 8 | fort st. john
# Processing Record 13 of Set 8 | kolonia town
# Processing Record 14 of Set 8 | melfi
# Processing Record 15 of Set 8 | columbia falls
# Processing Record 16 of Set 8 | flying fish cove
# Processing Record 17 of Set 8 | bubaque
# Processing Record 18 of Set 8 | konakovo
# Processing Record 19 of Set 8 | maua
# Processing Record 20 of Set 8 | katabu
# Processing Record 21 of Set 8 | calama
# Processing Record 22 of Set 8 | villa gesell
# Processing Record 23 of Set 8 | laojunmiao
# Processing Record 24 of Set 8 | keflavik
# Processing Record 25 of Set 8 | dapa
# Processing Record 26 of Set 8 | sitka
# Processing Record 27 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 28 of Set 8 | enewetak
# Processing Record 29 of Set 8 | yugorsk
# Processing Record 30 of Set 8 | paradise point
# Processing Record 31 of Set 8 | galliano
# Processing Record 32 of Set 8 | howard springs
# Processing Record 33 of Set 8 | argo
# Processing Record 34 of Set 8 | hobyo
# Processing Record 35 of Set 8 | guigang
# Processing Record 36 of Set 8 | afaahiti
# Processing Record 37 of Set 8 | kishtwar
# Processing Record 38 of Set 8 | nova xavantina
# Processing Record 39 of Set 8 | sandnessjoen
# Processing Record 40 of Set 8 | karagandy
# Processing Record 41 of Set 8 | jiaojiang
# Processing Record 42 of Set 8 | candon
# Processing Record 43 of Set 8 | kiffa
# Processing Record 44 of Set 8 | kalampaka
# Processing Record 45 of Set 8 | camacupa
# Processing Record 46 of Set 8 | kermit
# Processing Record 47 of Set 8 | nar'yan-mar
# Processing Record 48 of Set 8 | namtsy
# Processing Record 49 of Set 8 | prince rupert
# Processing Record 0 of Set 9 | arraias
# Processing Record 1 of Set 9 | remire-montjoly
# Processing Record 2 of Set 9 | iraucuba
# Processing Record 3 of Set 9 | olinda
# Processing Record 4 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 5 of Set 9 | long beach
# Processing Record 6 of Set 9 | kabalo
# Processing Record 7 of Set 9 | ulsteinvik
# Processing Record 8 of Set 9 | sabang
# Processing Record 9 of Set 9 | itoman
# Processing Record 10 of Set 9 | badulla
# Processing Record 11 of Set 9 | lerwick
# Processing Record 12 of Set 9 | san clemente del tuyu
# Processing Record 13 of Set 9 | muisne
# Processing Record 14 of Set 9 | sinabang
# Processing Record 15 of Set 9 | liman
# Processing Record 16 of Set 9 | bikin
# Processing Record 17 of Set 9 | novoagansk
# Processing Record 18 of Set 9 | gazojak
# Processing Record 19 of Set 9 | yuzhno-kurilsk
# Processing Record 20 of Set 9 | pacasmayo
# Processing Record 21 of Set 9 | rio preto da eva
# Processing Record 22 of Set 9 | langsa
# Processing Record 23 of Set 9 | mount isa
# Processing Record 24 of Set 9 | hameenkyro
# Processing Record 25 of Set 9 | fada
# Processing Record 26 of Set 9 | georgetown
# Processing Record 27 of Set 9 | burabay
# Processing Record 28 of Set 9 | luderitz
# Processing Record 29 of Set 9 | tarawa
# Processing Record 30 of Set 9 | bolgatanga
# Processing Record 31 of Set 9 | pangai
# Processing Record 32 of Set 9 | bandar seri begawan
# Processing Record 33 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 34 of Set 9 | gandajika
# Processing Record 35 of Set 9 | yilan
# Processing Record 36 of Set 9 | al-`ula
# City not found. Skipping...
# Processing Record 37 of Set 9 | antofagasta
# Processing Record 38 of Set 9 | vrangel'
# Processing Record 39 of Set 9 | polyarnyy
# Processing Record 40 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 41 of Set 9 | island harbour
# Processing Record 42 of Set 9 | turkmenbasy
# Processing Record 43 of Set 9 | fabens
# Processing Record 44 of Set 9 | cole harbour
# Processing Record 45 of Set 9 | puerto baquerizo moreno
# Processing Record 46 of Set 9 | dabhol
# Processing Record 47 of Set 9 | al kharijah
# Processing Record 48 of Set 9 | front royal
# Processing Record 49 of Set 9 | yallahs
# Processing Record 0 of Set 10 | mikuni
# Processing Record 1 of Set 10 | pauini
# Processing Record 2 of Set 10 | dayr hafir
# Processing Record 3 of Set 10 | kisangani
# Processing Record 4 of Set 10 | shiprock
# Processing Record 5 of Set 10 | uyar
# Processing Record 6 of Set 10 | whangarei
# Processing Record 7 of Set 10 | china
# Processing Record 8 of Set 10 | loei
# Processing Record 9 of Set 10 | murghob
# Processing Record 10 of Set 10 | tegueste
# Processing Record 11 of Set 10 | shetpe
# Processing Record 12 of Set 10 | elumalai
# Processing Record 13 of Set 10 | yuncheng
# Processing Record 14 of Set 10 | cortland
# Processing Record 15 of Set 10 | ola
# Processing Record 16 of Set 10 | san juan de miraflores
# Processing Record 17 of Set 10 | kodinsk
# Processing Record 18 of Set 10 | bemidji
# Processing Record 19 of Set 10 | paita
# Processing Record 20 of Set 10 | midelt
# Processing Record 21 of Set 10 | kurumkan
# Processing Record 22 of Set 10 | nabire
# Processing Record 23 of Set 10 | laguna
# Processing Record 24 of Set 10 | guatrache
# Processing Record 25 of Set 10 | akjoujt
# Processing Record 26 of Set 10 | kill devil hills
# Processing Record 27 of Set 10 | qarqin
# Processing Record 28 of Set 10 | lethem
# Processing Record 29 of Set 10 | abepura
# Processing Record 30 of Set 10 | vila franca do campo
# Processing Record 31 of Set 10 | urengoy
# Processing Record 32 of Set 10 | yashikira
# Processing Record 33 of Set 10 | taixing
# Processing Record 34 of Set 10 | kailua-kona
# Processing Record 35 of Set 10 | chuzhou
# Processing Record 36 of Set 10 | eremo
# Processing Record 37 of Set 10 | argudan
# Processing Record 38 of Set 10 | el porvenir
# Processing Record 39 of Set 10 | biltine
# Processing Record 40 of Set 10 | alaghsas
# Processing Record 41 of Set 10 | nouadhibou
# Processing Record 42 of Set 10 | inongo
# Processing Record 43 of Set 10 | kristiansund
# Processing Record 44 of Set 10 | carutapera
# Processing Record 45 of Set 10 | lucheng
# Processing Record 46 of Set 10 | danao
# Processing Record 47 of Set 10 | tsiombe
# Processing Record 48 of Set 10 | massawa
# Processing Record 49 of Set 10 | brisas de zicatela
# Processing Record 0 of Set 11 | ardestan
# Processing Record 1 of Set 11 | gabu
# Processing Record 2 of Set 11 | mount gambier
# Processing Record 3 of Set 11 | petropavlovskaya
# Processing Record 4 of Set 11 | at taj
# Processing Record 5 of Set 11 | selty
# Processing Record 6 of Set 11 | acapulco de juarez
# Processing Record 7 of Set 11 | cockburn town
# Processing Record 8 of Set 11 | arkalyk
# Processing Record 9 of Set 11 | mil'kovo
# Processing Record 10 of Set 11 | grand falls-windsor
# Processing Record 11 of Set 11 | afikpo
# Processing Record 12 of Set 11 | shimoda
# Processing Record 13 of Set 11 | cape coast
# Processing Record 14 of Set 11 | kingaroy
# Processing Record 15 of Set 11 | pimentel
# Processing Record 16 of Set 11 | wuyang
# Processing Record 17 of Set 11 | jianshui
# Processing Record 18 of Set 11 | quellon
# Processing Record 19 of Set 11 | beckenham
# Processing Record 20 of Set 11 | princeville
# Processing Record 21 of Set 11 | salavan
# Processing Record 22 of Set 11 | santa ana de yacuma
# Processing Record 23 of Set 11 | vorkuta
# Processing Record 24 of Set 11 | aras-asan
# Processing Record 25 of Set 11 | mitu
# Processing Record 26 of Set 11 | egilsstadir
# Processing Record 27 of Set 11 | chabahar
# Processing Record 28 of Set 11 | rikaze
# Processing Record 29 of Set 11 | forster
# Processing Record 30 of Set 11 | kimbe
# Processing Record 31 of Set 11 | kramfors
# Processing Record 32 of Set 11 | ulanhot
# Processing Record 33 of Set 11 | kruhlaye
# Processing Record 34 of Set 11 | belawan
# Processing Record 35 of Set 11 | mount darwin
# Processing Record 36 of Set 11 | tindouf
# Processing Record 37 of Set 11 | bandarbeyla
# Processing Record 38 of Set 11 | mossel bay
# Processing Record 39 of Set 11 | kutum
# Processing Record 40 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 41 of Set 11 | am timan
# Processing Record 42 of Set 11 | ilek
# Processing Record 43 of Set 11 | zadar
# Processing Record 44 of Set 11 | saratamata
# City not found. Skipping...
# Processing Record 45 of Set 11 | ghanzi
# Processing Record 46 of Set 11 | trail
# Processing Record 47 of Set 11 | motueka
# Processing Record 48 of Set 11 | contai
# Processing Record 49 of Set 11 | ta`u
# Processing Record 0 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 1 of Set 12 | inari
# Processing Record 2 of Set 12 | kavaratti
# Processing Record 3 of Set 12 | kaba
# Processing Record 4 of Set 12 | la barca
# Processing Record 5 of Set 12 | baiona
# Processing Record 6 of Set 12 | mandalgovi
# Processing Record 7 of Set 12 | turkestan
# Processing Record 8 of Set 12 | christchurch
# Processing Record 9 of Set 12 | broken hill
# Processing Record 10 of Set 12 | lembar
# City not found. Skipping...
# Processing Record 11 of Set 12 | sandakan
# Processing Record 12 of Set 12 | papao
# Processing Record 13 of Set 12 | bar
# Processing Record 14 of Set 12 | kasongo-lunda
# Processing Record 15 of Set 12 | cruzeiro do sul
# Processing Record 16 of Set 12 | crane
# Processing Record 17 of Set 12 | boca suno
# Processing Record 18 of Set 12 | challapata
# Processing Record 19 of Set 12 | acarau
# Processing Record 20 of Set 12 | al bayda'
# Processing Record 21 of Set 12 | tongren
# Processing Record 22 of Set 12 | praia
# Processing Record 23 of Set 12 | kuanda
# Processing Record 24 of Set 12 | alfredo v. bonfil
# Processing Record 25 of Set 12 | yarkovo
# Processing Record 26 of Set 12 | usogorsk
# Processing Record 27 of Set 12 | fontanelas
# Processing Record 28 of Set 12 | senanga
# Processing Record 29 of Set 12 | cananeia
# Processing Record 30 of Set 12 | porto novo
# Processing Record 31 of Set 12 | walvis bay
# Processing Record 32 of Set 12 | kamennomostskiy
# Processing Record 33 of Set 12 | reggane
# Processing Record 34 of Set 12 | kalmunai
# Processing Record 35 of Set 12 | selkirk
# Processing Record 36 of Set 12 | galle
# Processing Record 37 of Set 12 | swakopmund
# Processing Record 38 of Set 12 | essaouira
# Processing Record 39 of Set 12 | ras gharib
# City not found. Skipping...
# Processing Record 40 of Set 12 | pana
# Processing Record 41 of Set 12 | ambovombe
# Processing Record 42 of Set 12 | pimenta bueno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    la passe  45.5549   -0.8967     10.13        78          99        8.37
# 1  bredasdorp -34.5322   20.0403     17.32        70         100        4.70
# 2      ixtapa  20.7000 -105.2000     27.90        54         100        1.79
# 3       rasht  37.2808   49.5832     12.31        90         100        0.99
# 4   grytviken -54.2811  -36.5092      3.24        97         100        3.28
#
#   Country        Date
# 0      FR  1702493152
# 1      ZA  1702493153
# 2      MX  1702493153
# 3      IR  1702493153
# 4      GS  1702493153

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          la passe  45.5549   -0.8967     10.13        78          99
# 1        bredasdorp -34.5322   20.0403     17.32        70         100
# 2            ixtapa  20.7000 -105.2000     27.90        54         100
# 3             rasht  37.2808   49.5832     12.31        90         100
# 4         grytviken -54.2811  -36.5092      3.24        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              8.37      FR  1702493152
# 1              4.70      ZA  1702493153
# 2              1.79      MX  1702493153
# 3              0.99      IR  1702493153
# 4              3.28      GS  1702493153

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    marker = "*",
    alpha = .5,
    linewidths = .5,
    edgecolor = "#4CBB17"
)

# Incorporate the other graph properties
plt.title("Comparing Cities Max Latitude Against Temperature (%s)" % time.strftime("%m/%d/%Y"))
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature in Celcius")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    marker = "*",
    linewidths = .5,
    alpha = .5,
    edgecolor = "#4CBB17",
    label = "Cities"
)
# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime ("%m/%d/%y"))
plt.xlabel("City Latitude")
plt.ylabel("Percentage of Humidity")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    marker = "*",
    linewidths = .5,
    alpha = .5,
    edgecolor = "#4CBB17",
    label = "Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime ("%m/%d/%y"))
plt.xlabel("City Latitude")
plt.ylabel("Percentage of Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    marker = "*",
    linewidths = .5,
    alpha = .5,
    edgecolor = "#4CBB17",
    label = "Cities"
)


# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime ("%m/%d/%y"))
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x_values, y_values, title, text_coordinates):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
    regression = x_values * slope + intercept
    line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regression, "r-")
    plt.annotate(line, text_coordinates,fontsize = 12, color = "#4CBB17")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"R-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        la passe  45.5549   -0.8967     10.13        78          99
# 2          ixtapa  20.7000 -105.2000     27.90        54         100
# 3           rasht  37.2808   49.5832     12.31        90         100
# 5          albany  42.6001  -73.9662      4.21        60          50
# 6        hamilton  39.1834  -84.5333      7.44        44           0
#
#          Wind Speed Country        Date
# City_ID
# 0              8.37      FR  1702493152
# 2              1.79      MX  1702493153
# 3              0.99      IR  1702493153
# 5              0.45      US  1702492957
# 6              1.54      US  1702493153

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        bredasdorp -34.5322   20.0403     17.32        70         100
# 4         grytviken -54.2811  -36.5092      3.24        97         100
# 9            avarua -21.2078 -159.7750     26.03        89          75
# 22         waitangi -43.9535 -176.5597     10.46        90          89
# 23        adamstown -25.0660 -130.1015     23.25        83          98
#
#          Wind Speed Country        Date
# City_ID
# 1              4.70      ZA  1702493153
# 4              3.28      GS  1702493153
# 9              5.14      CK  1702493154
# 22             4.92      NZ  1702493155
# 23             4.72      PN  1702493155

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
linear_regression_plot(x_values, y_values, "Max Temp", (5,-12))
# Out:
# R-value is: 0.7102987057145891

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
linear_regression_plot(x_values, y_values, "Max Temp", (-60,40))
# Out:
# R-value is: 0.35182792607641905

# %% [markdown]
# **Discussion about the linear relationship:** The latitude and max temps for the northern hemisphere have a higher correlation. The Southern Hempisphere has a positive correlation between latitude and max temps but it is not as reliable as the northern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
